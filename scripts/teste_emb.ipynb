# %%
import numpy as np

# Amazon books

seq2vec_embeddings = np.load('/workspace/gregorio/time-embeddings/results/embeddings/test/amazon-books/Seq2Vec/learning_rate=0.025@negative_exp=-0.5@negative_samples=7@regularization=1e-06@subsample=0.001@time_threshold=730@w_size=10@epochs=100/items.npy')

item2vec_embeddings = np.load('/workspace/gregorio/time-embeddings/results/embeddings/test/amazon-books/Item2Vec_itemSim/learning_rate=0.025@negative_exp=-0.5@negative_samples=7@regularization=1e-06@subsample=0.001@w_size=10@epochs=100/items.npy')

print('Amazon books:')
print('item2vec_embeddings shape:', item2vec_embeddings.shape)
print('seq2vec_embeddings shape:', seq2vec_embeddings.shape)
print('\n')

# CiaoDVD

seq2vec_embeddings = np.load('/workspace/gregorio/time-embeddings/results/embeddings/test/ciaodvd/Seq2Vec/learning_rate=0.025@negative_exp=-0.5@negative_samples=7@regularization=1e-06@subsample=0.001@time_threshold=730@w_size=10@epochs=100/items.npy')

item2vec_embeddings = np.load('/workspace/gregorio/time-embeddings/results/embeddings/test/ciaodvd/Item2Vec_itemSim/learning_rate=0.025@negative_exp=-0.5@negative_samples=7@regularization=1e-06@subsample=0.001@w_size=10@epochs=100/items.npy')

print('Amazon books:')
print('item2vec_embeddings shape:', item2vec_embeddings.shape)
print('seq2vec_embeddings shape:', seq2vec_embeddings.shape)
print('\n')

# Retail rocket

seq2vec_embeddings = np.load('/workspace/gregorio/time-embeddings/results/embeddings/test/retailrocket-transactions/Seq2Vec/learning_rate=0.025@negative_exp=-0.5@negative_samples=7@regularization=1e-06@subsample=0.001@time_threshold=365@w_size=10@epochs=20/items.npy')

item2vec_embeddings = np.load('/workspace/gregorio/time-embeddings/results/embeddings/test/retailrocket-transactions/Item2Vec_itemSim/learning_rate=0.25@negative_exp=-1.0@negative_samples=7@regularization=1e-06@subsample=0.0001@w_size=10@epochs=20/items.npy')

print('Retail rocket:')
print('item2vec_embeddings shape:', item2vec_embeddings.shape)
print('seq2vec_embeddings shape:', seq2vec_embeddings.shape)
print('\n')
# Out:
# Amazon books:
# item2vec_embeddings shape: (11017, 50)
# seq2vec_embeddings shape: (11017, 50)
#
#
# Retail rocket:
# item2vec_embeddings shape: (1330, 50)
# seq2vec_embeddings shape: (1330, 50)

# %%
import numpy as np

seq2vec_embeddings = np.load('/workspace/gregorio/time-embeddings/results/embeddings/test/amazon-games/Seq2Vec/learning_rate=0.025@negative_exp=-0.5@negative_samples=7@regularization=1e-06@subsample=0.001@time_threshold=730@w_size=10@epochs=50/items.npy')

item2vec_embeddings = np.load('/workspace/gregorio/time-embeddings/results/embeddings/test/ciaodvd/Item2Vec_itemSim/learning_rate=0.025@negative_exp=1@negative_samples=7@regularization=1e-06@subsample=0.001@w_size=10@epochs=20/items.npy')

print(item2vec_embeddings.shape)
print(seq2vec_embeddings.shape)
